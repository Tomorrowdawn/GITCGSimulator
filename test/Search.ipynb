# %%
import sys
sys.path.append('..')
from src.core.GameInstance import apply_react, reaction, GameInstance
from src.core.GameState import Location, Aura, GameState, Box
from src.game import activate, Game
b1 = Box(['Diluc','Sucrose','Diluc'],[])
b2 = Box(['Diluc','Diluc','Sucrose'],[])
state = GameState(b1,b2)
g = Game()
g.initiate(state)

# %%
from agent.alphabeta import Searcher

# %%
Master = Searcher(player = 1)
Rival = Searcher(player = 2)

# %%
while not g.terminated():
    player = g.mover
    print("mover = ", g.mover)
    if g.mover == 1:
        m, s, d = Master.search(5, g)
        #m, s, d = Rival.search(5, g)
        #m = g.getIns(1, 'switch next')
        g.proceed(m,False, Master.callback)
        nodes = Master.nodes
        print("move = ", m)
        print("depth = {}, total nodes = {}, score = {}".format(d,nodes,s))
    elif g.mover == 2:
        #m = input("your move:")
        #m = g.getIns(2, m)
        m, s, d = Rival.search(5, g)
        g.proceed(m,False, Rival.callback)
        print("move = ",m)
        #nodes = Rival.nodes
    else:
        print("mover = ", g.mover)
        break
    #print("player {} makes a move {}".format(player, m))
    print("hp distribution: ")
    print("p1 = ",[c.hp for c in g.g.p1.char],'\t\t','p2 = ', [c.hp for c in g.g.p2.char] )
    print("p1 active = ",g.g.p1.history['active'], ' p2 active = ', g.g.p2.history['active'])
    print("p1 end = ",g.g.p1.history['endround'], 'p2 end = ',g.g.p2.history['endround'])
    print()
# Out:
# mover =  1
# scores =  [3, 2, 0, 0, 0]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 6, total nodes = 8923, score = 3
# hp distribution:
# p1 =  [10, 10, 10] 		 p2 =  [7, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [0, -1, -3, -3, -3]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [7, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [3, 2, 0, 0, 0]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 8, total nodes = 10444, score = 3
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [0, -1, -3, -3, -3]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [0, 0, 0]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 17, total nodes = 14903, score = 0
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  1  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [0, 0, 0]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [0, 0, 0]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 37, total nodes = 17677, score = 0
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  2  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [0, 0, 0]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [0]
# move =  EndRound(player_id=1, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 99, total nodes = 4950, score = 0
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  2  p2 active =  2
# p1 end =  True p2 end =  False
#
# mover =  2
# scores =  [0]
# move =  EndRound(player_id=2, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [3, 2, 0, 0, 0]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 7, total nodes = 12626, score = 3
# hp distribution:
# p1 =  [4, 10, 10] 		 p2 =  [4, 10, 7]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [0, -2, -3, -3, -3]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [4, 10, 7] 		 p2 =  [4, 10, 7]
# p1 active =  1  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [5, 3, 0, 0, 0]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 8, total nodes = 14266, score = 5
# hp distribution:
# p1 =  [4, 10, 7] 		 p2 =  [3, 9, 4]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-2, -3, -5, -5, -5]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [2, 2, 2]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 17, total nodes = 15356, score = 2
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  2  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-2, -2, -2]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [2, 2, 2]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 35, total nodes = 14881, score = 2
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  0  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-2, -2, -2]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [2]
# move =  EndRound(player_id=1, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 99, total nodes = 4950, score = 2
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  0  p2 active =  0
# p1 end =  True p2 end =  False
#
# mover =  2
# scores =  [-2]
# move =  EndRound(player_id=2, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [3, 9, 4]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [5, 4, 2, 2, 2]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 7, total nodes = 14153, score = 5
# hp distribution:
# p1 =  [4, 7, 7] 		 p2 =  [0, 9, 4]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-2, -3, -5, -5, -5]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [1, 7, 7] 		 p2 =  [0, 9, 4]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [5, 4, 2, 2, 10, 2]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='burst')
# depth = 8, total nodes = 16054, score = 10
# hp distribution:
# p1 =  [1, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-9, -9, -10, -10, -10]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [9, 9, 9]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 17, total nodes = 15731, score = 9
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  2  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-9, -9, -9]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [9, 9, 9]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 35, total nodes = 15095, score = 9
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  1  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-9, -9, -9]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [9]
# move =  EndRound(player_id=1, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 99, total nodes = 4950, score = 9
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  1  p2 active =  1
# p1 end =  True p2 end =  False
#
# mover =  2
# scores =  [-9]
# move =  EndRound(player_id=2, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 1, 4]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
#
# mover =  1
# scores =  [11, 11, 9, 9, 9]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 10, total nodes = 15596, score = 11
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [0, 0, 3]
# p1 active =  1  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  2
# scores =  [-7, -9, -11]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=3), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# hp distribution:
# p1 =  [0, 4, 6] 		 p2 =  [0, 0, 3]
# p1 active =  2  p2 active =  2
# p1 end =  False p2 end =  False
#
# mover =  1
