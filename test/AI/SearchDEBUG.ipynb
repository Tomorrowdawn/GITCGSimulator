# %%
import sys
sys.path.append('../..')
from src.core.GameInstance import apply_react, reaction, GameInstance
from src.core.GameState import Location, Aura, GameState, Box
from src.game import activate, Game
b1 = Box(['Diluc','Kaeya','Sucrose'],[])
b2 = Box(['Diluc','Kaeya','Sucrose'],[])
state = GameState(b1,b2)
g = Game()
g.initiate(state)

# %%
from agent.alphabeta import Searcher
from src.core.Event import Event, Death, Switch

# %%
def input_callback(g, event, *args):
    print("yes i am here")
    if isinstance(event, Death) and g.history['phase'] == 'deathswitch':
        active = g.getactive(event.player_id)
        direct = int(input('your switch(1 for next, -1 for previous):'))
        return Switch(g.nexteid(), event.eid, event.player_id, active, direct)
    else:
        return Event(-1,-1,-1)

# %%
#player = int(input('your player_id is:'))
player = 1
Master = Searcher(3 - player)
Rival = Searcher(player)
def callback(g, event, *args):
    if event.player_id == player:
        #return input_callback(g,event,*args)
        return Rival.callback(g,event, *args)
    else:
        return Master.callback(g,event,*args)
while not g.terminated():
    #player = 1
    print("mover = ", g.mover)
    if g.mover != player:
        m, s, d = Master.search(5, g)
        #m, s, d = Rival.search(5, g)
        #m = g.getIns(1, 'switch next')
        print("move = ", m)
        g.proceed(m,False, callback)
        nodes = Master.nodes
        print("depth = {}, total nodes = {}, score = {}".format(d,nodes,s))
    elif g.mover == player:
        #m = input("your move:")
        #m = g.getIns(player, m)
        m, s, d = Rival.search(10, g)
        g.proceed(m,False, callback)
        print("move = ",m)
        nodes = Rival.nodes
        print("depth = {}, total nodes = {}, score = {}".format(d,nodes,s))
    else:
        print("mover = ", g.mover)
        break
    #print("player {} makes a move {}".format(player, m))
    print("hp distribution: ")
    print("p1 = ",[c.hp for c in g.g.p1.char],'\t\t','p2 = ', [c.hp for c in g.g.p2.char] )
    print("p1 active = ",g.g.p1.history['active'], ' p2 active = ', g.g.p2.history['active'])
    print("p1 end = ",g.g.p1.history['endround'], 'p2 end = ',g.g.p2.history['endround'])
    print("p1 aura = ", g.g.p1.getAura(), ' p2 aura = ', g.g.p2.getAura())
    print()
# Out:
# mover =  1
# scores =  [0, 0, 0, -2, -16]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 10, total nodes = 9251, score = 0
# hp distribution:
# p1 =  [10, 10, 10] 		 p2 =  [7, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.empty: 0>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [0, 0, -1, -1, -15]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 9, total nodes = 4445, score = 0
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [7, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-1, -3, -2, -2, -10]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 10, total nodes = 8672, score = -1
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [0, 0, 0, 1, 1]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=-1)
# depth = 9, total nodes = 5167, score = 1
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  2
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-1, -1, -4]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 10, total nodes = 10622, score = -1
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  1  p2 active =  2
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [0, 0, 0, 1, 1]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=-1)
# depth = 9, total nodes = 5620, score = 1
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-3, -2, -2]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=-1)
# depth = 11, total nodes = 11579, score = -2
# hp distribution:
# p1 =  [7, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [1, 1, 1, 0, -4]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=3, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=0, cryo=3, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 9, total nodes = 5772, score = 1
# hp distribution:
# p1 =  [2, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.empty: 0>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-2.799999999999997]
# move =  EndRound(player_id=1, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 11, total nodes = 10864, score = -2.799999999999997
# hp distribution:
# p1 =  [2, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  1
# p1 end =  True p2 end =  False
# p1 aura =  [<Aura.empty: 0>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [2.799999999999997]
# move =  EndRound(player_id=2, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 9, total nodes = 5192, score = 2.799999999999997
# hp distribution:
# p1 =  [2, 10, 10] 		 p2 =  [4, 10, 10]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.empty: 0>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-2.799999999999997, -4, -3, -3, -17]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 9, total nodes = 10876, score = -2.799999999999997
# hp distribution:
# p1 =  [2, 10, 10] 		 p2 =  [4, 7, 10]
# p1 active =  0  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.empty: 0>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.pyro: 1>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [2, 2.799999999999997, 0, 0, -14]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=1, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=2, white=0, omni=0), real_dice_pattern=DicePattern(pyro=0, cryo=1, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=2, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='na')
# depth = 8, total nodes = 5363, score = 2.799999999999997
# hp distribution:
# p1 =  [0, 10, 10] 		 p2 =  [4, 7, 10]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.pyro: 1>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-3.1999999999999993, -5, -4, -12]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=3, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=0, cryo=3, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 11, total nodes = 10382, score = -3.1999999999999993
# hp distribution:
# p1 =  [0, 10, 10] 		 p2 =  [4, 2, 10]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.empty: 0>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [2, 2, 2, 2, 2, -7]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=4, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=0, cryo=4, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=4, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='burst')
# depth = 9, total nodes = 5224, score = 2
# hp distribution:
# p1 =  [0, 9, 10] 		 p2 =  [4, 2, 10]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-4, -3.1999999999999993]
# move =  EndRound(player_id=1, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 11, total nodes = 9387, score = -3.1999999999999993
# hp distribution:
# p1 =  [0, 9, 10] 		 p2 =  [4, 2, 10]
# p1 active =  1  p2 active =  1
# p1 end =  True p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [3, 4, 4]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=-1)
# depth = 8, total nodes = 4182, score = 4
# hp distribution:
# p1 =  [0, 7, 10] 		 p2 =  [4, 2, 10]
# p1 active =  1  p2 active =  0
# p1 end =  True p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [4]
# move =  EndRound(player_id=2, dice_pattern=None, real_dice_pattern=None, dice_instance=None)
# depth = 9, total nodes = 4587, score = 4
# hp distribution:
# p1 =  [0, 7, 10] 		 p2 =  [4, 2, 10]
# p1 active =  1  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-4.399999999999999, -4.799999999999997, -3.799999999999997, -17.799999999999997]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 10, total nodes = 9607, score = -3.799999999999997
# hp distribution:
# p1 =  [0, 7, 10] 		 p2 =  [4, 2, 10]
# p1 active =  2  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.empty: 0>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  2
# scores =  [4.800000000000001, 0.8000000000000007, 3.3999999999999986, 3.3999999999999986, -12.2]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 9, total nodes = 5232, score = 4.800000000000001
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [4, 2, 10]
# p1 active =  2  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.pyro: 1>, <Aura.empty: 0>, <Aura.empty: 0>]
#
# mover =  1
# scores =  [-5.4, -3.8000000000000007, -4.800000000000001, -16.8]
# move =  UseKit(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=1, geo=0, black=2, white=0, omni=0), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=1, geo=0, black=2, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='na')
# depth = 11, total nodes = 10374, score = -3.8000000000000007
# hp distribution:
# p1 =  [0, 7, 7] 		 p2 =  [3, 1, 9]
# p1 active =  2  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  2
# scores =  [8, 8, 8, 8, -6.199999999999999]
# move =  UseKit(player_id=2, dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), real_dice_pattern=DicePattern(pyro=3, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=0), dice_instance=DiceInstance(omni=3, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), kit='skill')
# depth = 9, total nodes = 5186, score = 8
# hp distribution:
# p1 =  [0, 7, 4] 		 p2 =  [3, 1, 9]
# p1 active =  2  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  1
# scores =  [-1000, -1000, -4.399999999999999, -9.8]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 13, total nodes = 10076, score = -4.399999999999999
# hp distribution:
# p1 =  [0, 7, 4] 		 p2 =  [3, 1, 9]
# p1 active =  1  p2 active =  0
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  2
# scores =  [4.399999999999999, 2.3999999999999986, -0.1999999999999993]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 10, total nodes = 4422, score = 4.399999999999999
# hp distribution:
# p1 =  [0, 5, 4] 		 p2 =  [3, 1, 9]
# p1 active =  1  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  1
# scores =  [-8, -8, -4.399999999999999, -8.399999999999999]
# move =  Switch(player_id=1, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 14, total nodes = 9978, score = -4.399999999999999
# hp distribution:
# p1 =  [0, 5, 4] 		 p2 =  [3, 1, 9]
# p1 active =  2  p2 active =  1
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.pyro: 1>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  2
# scores =  [12, 5, 2.4000000000000004]
# move =  Switch(player_id=2, dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), real_dice_pattern=DicePattern(pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0, black=0, white=0, omni=1), dice_instance=DiceInstance(omni=1, pyro=0, cryo=0, hydro=0, electro=0, dendro=0, anemo=0, geo=0), direction=1)
# depth = 12, total nodes = 4940, score = 12
# hp distribution:
# p1 =  [0, 5, 0] 		 p2 =  [3, 1, 9]
# p1 active =  1  p2 active =  2
# p1 end =  False p2 end =  False
# p1 aura =  [<Aura.died: 9>, <Aura.cryo: 2>, <Aura.died: 9>]  p2 aura =  [<Aura.empty: 0>, <Aura.pyro: 1>, <Aura.pyro: 1>]
#
# mover =  1
